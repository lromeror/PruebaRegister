# %%
import pandas as pd

# %%
data = pd.read_excel("Registro Conferencia de WiDS Guayaquil@ESPOL 2024 (respuestas).xlsx",engine="openpyxl")
data.head()
# Out:
#            Marca temporal            Nombres        Apellidos  \
# 0 2024-06-26 22:39:27.889    Domenica Nicole    Massay Cumbe
# 1 2024-06-28 12:21:42.076  Allison Deyaneira  Palma Cárdenas
# 2 2024-06-28 14:37:54.602     Evelyn Vanessa   García Moreira
# 3 2024-06-29 11:38:36.727   Adamaris Yadira   Troya Cortazár
# 4 2024-06-29 11:52:03.084     Wilson Miguel   Chugcho Freire
#
#   Teléfono (Móvil)    Ocupación                Correo electrónico:  \
# 0       0979037677   Estudiante               dmassay@espol.edu.ec
# 1       0995929596   Estudiante              allpcard@espol.edu.ec
# 2       0984632604  Profesional  evegarcia@tecnologicoargos.edu.ec
# 3       0986569642   Estudiante               aytroya@espol.edu.ec
# 4       0992058733   Estudiante          miguelchugcho71@gmail.com
#
#                        Carrera                                Universidad  \
# 0  Administración de empresas   Escuela Superior Politécnica del Litoral
# ...

# %%
def formatDf(df):
    df_nuevo = df.copy()
    df_nuevo = df_nuevo.drop(["Marca temporal","¿Desea recibir notificaciones de futuros eventos?","¿Estás seguro de que podrás asistir al evento de forma presencial?"],axis=1)
    return df_nuevo

df_nuevo = formatDf(data)
df_nuevo

## Desde la visión de verificar asistencia :
# * ¿Desea recibir notificaciones de futuros eventos?
# * ¿Estás seguro de que podrás asistir al evento de forma presencial?
# Out:
#               Nombres            Apellidos Teléfono (Móvil)    Ocupación  \
# 0     Domenica Nicole        Massay Cumbe        0979037677   Estudiante
# 1   Allison Deyaneira      Palma Cárdenas        0995929596   Estudiante
# 2      Evelyn Vanessa       García Moreira       0984632604  Profesional
# 3    Adamaris Yadira       Troya Cortazár        0986569642   Estudiante
# 4      Wilson Miguel       Chugcho Freire        0992058733   Estudiante
# ..                ...                  ...              ...          ...
# 68    Gabriela Aimar        Merino Méndez        0995158764   Estudiante
# 69        Mafer Avril         Pérez García       0989320432   Estudiante
# 70      Alexander Uli         Goussas Egas       0995764993  Profesional
# 71              Ariel              Armijos       0985146512  Profesional
# 72        Juan Carlos  Echeverría Vallazza       0999395863  Profesional
#
#                   Correo electrónico:  \
# 0                dmassay@espol.edu.ec
# ...

# %%
df.drop()
